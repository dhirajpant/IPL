# %%
#importing all necessary libraries
import pandas as pd
import numpy as np

# %%
#importing the dataset
df=pd.read_csv('IPL Matches 2008-2020.csv')

# %%
#shows us first few rows of the datset
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
#shows us last few rows from the dataset
df.tail()
# Out:
#           id       city        date player_of_match  \
# 811  1216547      Dubai  2020-09-28  AB de Villiers
# 812  1237177      Dubai  2020-11-05       JJ Bumrah
# 813  1237178  Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180  Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181      Dubai  2020-11-10        TA Boult
#
#                                    venue  neutral_venue  \
# 811  Dubai International Cricket Stadium              0
# 812  Dubai International Cricket Stadium              0
# 813                 Sheikh Zayed Stadium              0
# 814                 Sheikh Zayed Stadium              0
# 815  Dubai International Cricket Stadium              0
#
#                            team1                team2          toss_winner  \
# 811  Royal Challengers Bangalore       Mumbai Indians       Mumbai Indians
# 812               Mumbai Indians       Delhi Capitals       Delhi Capitals
# 813  Royal Challengers Bangalore  Sunrisers Hyderabad  Sunrisers Hyderabad
# ...

# %%
#shows us some random given number of rows from the dataset
df.sample(5)
# Out:
#          id        city        date player_of_match  \
# 270  548328  Chandigarh  2012-04-18       G Gambhir
# 399  729281         NaN  2014-04-17       YS Chahal
# 417  729317         NaN  2014-04-30         B Kumar
# 341  598017   Bangalore  2013-04-16         V Kohli
# 117  419108  Chandigarh  2010-03-13       G Gambhir
#
#                                           venue  neutral_venue  \
# 270  Punjab Cricket Association Stadium, Mohali              0
# 399                     Sharjah Cricket Stadium              1
# 417         Dubai International Cricket Stadium              1
# 341                       M Chinnaswamy Stadium              0
# 117  Punjab Cricket Association Stadium, Mohali              0
#
#                            team1                        team2  \
# 270              Kings XI Punjab        Kolkata Knight Riders
# 399             Delhi Daredevils  Royal Challengers Bangalore
# 417               Mumbai Indians          Sunrisers Hyderabad
# ...

# %%
#tells us about the shape of rows and coloumns from the dataset
df.shape
# Out:
# (816, 17)

# %%
#performs some statistical calculation on the numeric coloumn in dataset 
df.describe()
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %%
#checks if there is missing values in the dataset or not
df.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
#tells the general information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
#checking the frequency of the MOM awards
MOM=df['player_of_match'].value_counts()
MOM
# Out:
# player_of_match
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# DA Warner         17
# MS Dhoni          17
#                   ..
# S Anirudha         1
# M Kartik           1
# R McLaren          1
# RJ Harris          1
# PJ Cummins         1
# Name: count, Length: 233, dtype: int64

# %%
#for top 10 players who have won MOM
MOM_10=MOM[0:10]
MOM_10
# Out:
# player_of_match
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# DA Warner         17
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# SK Raina          14
# V Kohli           13
# G Gambhir         13
# Name: count, dtype: int64

# %%
## Most number of tosses won
df['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 106
# Kolkata Knight Riders           98
# Chennai Super Kings             97
# Royal Challengers Bangalore     87
# Rajasthan Royals                87
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Sunrisers Hyderabad             57
# Deccan Chargers                 43
# Pune Warriors                   20
# Delhi Capitals                  20
# Gujarat Lions                   15
# Kochi Tuskers Kerala             8
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: count, dtype: int64

# %%
#most matches won by a team
df['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
#no of rain affected matches or matches where result is declared by DLS method
df['method'].value_counts()
# Out:
# method
# D/L    19
# Name: count, dtype: int64

# %%
#decision of captain after winning toss
df['toss_decision'].value_counts()
# Out:
# toss_decision
# field    496
# bat      320
# Name: count, dtype: int64

# %%
#no of matches played at neutral venues
df['neutral_venue'].value_counts()
# Out:
# neutral_venue
# 0    739
# 1     77
# Name: count, dtype: int64

# %%
#team winning by either runs or wickets or game tied
df['result'].value_counts()
# Out:
# result
# wickets    435
# runs       364
# tie         13
# Name: count, dtype: int64
